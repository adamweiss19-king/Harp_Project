# %%
## #API SETUP

import os
from google import genai
from google.genai import types

# Set up the environment variable for the Google Gemini API key
os.environ["GEMINI_API_KEY"] = "AIzaSyA9RqiZpY_tFYwQdm7Js_O3gT-uuUg4N-I"

# Set up the API key for Google Gemini AI
# Replace with your actual API key

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="what is the percentage of notes in a harmonica that are available in the A Major Richter tuning?",
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0) # Disables thinking
    ),
)
print(response.text)
